# %% [markdown]
# <a href="https://colab.research.google.com/github/Amt15/Pyspark/blob/main/pivot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark -q
# !pip install findspark -q

# %%
from pyspark.sql import SparkSession

spark = SparkSession.Builder()\
  .appName("understanding the pivot and unpivot")\
  .master("local[*]")\
  .enableHiveSupport()\
  .getOrCreate()

# %%
import pyspark
from pyspark.sql.functions import expr
#Create spark session
data = [("Banana",1000,"USA"), ("Carrots",1500,"USA"), ("Beans",1600,"USA"), \
      ("Orange",2000,"USA"),("Orange",2000,"USA"),("Banana",400,"China"), \
      ("Carrots",1200,"China"),("Beans",1500,"China"),("Orange",4000,"China"), \
      ("Banana",2000,"Canada"),("Carrots",2000,"Canada"),("Beans",2000,"Mexico")]

columns= ["Product","Amount","Country"]
df = spark.createDataFrame(data = data, schema = columns)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Amount: long (nullable = true)
#  |-- Country: string (nullable = true)
#
# +-------+------+-------+
# |Product|Amount|Country|
# +-------+------+-------+
# |Banana |1000  |USA    |
# |Carrots|1500  |USA    |
# |Beans  |1600  |USA    |
# |Orange |2000  |USA    |
# |Orange |2000  |USA    |
# |Banana |400   |China  |
# |Carrots|1200  |China  |
# |Beans  |1500  |China  |
# |Orange |4000  |China  |
# |Banana |2000  |Canada |
# |Carrots|2000  |Canada |
# |Beans  |2000  |Mexico |
# +-------+------+-------+

# %%
import pandas

hdf = df.toPandas()

# %% [markdown]
# pivot() function to rotate the data from one column into multiple columns. It is an aggregation where one of the grouping columns values is transposed into individual columns with distinct data. To get the total amount exported to each country of each product, will do group by Product, pivot by Country, and the sum of Amount.

# %%
pivotDF = df.groupBy("Product").pivot("Country").sum("Amount")
pivotDF.printSchema()
pivotDF.show(truncate=False)
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Canada: long (nullable = true)
#  |-- China: long (nullable = true)
#  |-- Mexico: long (nullable = true)
#  |-- USA: long (nullable = true)
#
# +-------+------+-----+------+----+
# |Product|Canada|China|Mexico|USA |
# +-------+------+-----+------+----+
# |Orange |null  |4000 |null  |4000|
# |Beans  |null  |1500 |2000  |1600|
# |Banana |2000  |400  |null  |1000|
# |Carrots|2000  |1200 |null  |1500|
# +-------+------+-----+------+----+

# %% [markdown]
# version 2.0 on-wards performance has been improved on Pivot, however, if you are using the lower version; note that pivot is a very expensive operation hence, it is recommended to provide column data (if known) as an argument to function as shown below.

# %%
countries = ["USA","China","Canada","Mexico"]
pivotDF = df.groupBy("Product").pivot("Country", countries).sum("Amount")
pivotDF.show(truncate=False)
# Out:
# +-------+----+-----+------+------+
# |Product|USA |China|Canada|Mexico|
# +-------+----+-----+------+------+
# |Orange |4000|4000 |null  |null  |
# |Beans  |1600|1500 |null  |2000  |
# |Banana |1000|400  |2000  |null  |
# |Carrots|1500|1200 |2000  |null  |
# +-------+----+-----+------+------+

# %%
pivotDF = df.groupBy("Product","Country") \
      .sum("Amount") \
      .groupBy("Product") \
      .pivot("Country") \
      .sum("sum(Amount)") 
pivotDF.show(truncate=False)
# Out:
# +-------+------+-----+------+----+
# |Product|Canada|China|Mexico|USA |
# +-------+------+-----+------+----+
# |Orange |null  |4000 |null  |4000|
# |Beans  |null  |1500 |2000  |1600|
# |Banana |2000  |400  |null  |1000|
# |Carrots|2000  |1200 |null  |1500|
# +-------+------+-----+------+----+

# %%
from pyspark.sql.functions import expr
unpivotExpr = "stack(3, 'Canada', Canada, 'China', China, 'Mexico', Mexico) as (Country,Total)"
unPivotDF = pivotDF.select("Product", expr(unpivotExpr)) \
    .where("Total is not null")
unPivotDF.show(truncate=False)
unPivotDF.show()
# Out:
# +-------+-------+-----+
# |Product|Country|Total|
# +-------+-------+-----+
# |Orange |China  |4000 |
# |Beans  |China  |1500 |
# |Beans  |Mexico |2000 |
# |Banana |Canada |2000 |
# |Banana |China  |400  |
# |Carrots|Canada |2000 |
# |Carrots|China  |1200 |
# +-------+-------+-----+
#
# +-------+-------+-----+
# |Product|Country|Total|
# +-------+-------+-----+
# | Orange|  China| 4000|
# |  Beans|  China| 1500|
# |  Beans| Mexico| 2000|
# | Banana| Canada| 2000|
# | Banana|  China|  400|
# |Carrots| Canada| 2000|
# |Carrots|  China| 1200|
# +-------+-------+-----+

# %%
import pandas as pd
import numpy as np
import seaborn as sn

df = sn.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
highlight = lambda x: ['background: red' if x.name in [6,3] else '' for i in x]
df.head(10).style.apply(highlight,axis=1)
# Out:
# <style type="text/css">
# #T_e8893_row3_col0, #T_e8893_row3_col1, #T_e8893_row3_col2, #T_e8893_row3_col3, #T_e8893_row3_col4, #T_e8893_row3_col5, #T_e8893_row3_col6, #T_e8893_row3_col7, #T_e8893_row3_col8, #T_e8893_row3_col9, #T_e8893_row6_col0, #T_e8893_row6_col1, #T_e8893_row6_col2, #T_e8893_row6_col3, #T_e8893_row6_col4, #T_e8893_row6_col5, #T_e8893_row6_col6, #T_e8893_row6_col7, #T_e8893_row6_col8, #T_e8893_row6_col9 {
#   background: red;
# }
# </style>
# <table id="T_e8893_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >carat</th>
#       <th class="col_heading level0 col1" >cut</th>
#       <th class="col_heading level0 col2" >color</th>
#       <th class="col_heading level0 col3" >clarity</th>
#       <th class="col_heading level0 col4" >depth</th>
#       <th class="col_heading level0 col5" >table</th>
#       <th class="col_heading level0 col6" >price</th>
#       <th class="col_heading level0 col7" >x</th>
#       <th class="col_heading level0 col8" >y</th>
#       <th class="col_heading level0 col9" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8893_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8893_row0_col0" class="data row0 col0" >0.230000</td>
#       <td id="T_e8893_row0_col1" class="data row0 col1" >Ideal</td>
#       <td id="T_e8893_row0_col2" class="data row0 col2" >E</td>
#       <td id="T_e8893_row0_col3" class="data row0 col3" >SI2</td>
#       <td id="T_e8893_row0_col4" class="data row0 col4" >61.500000</td>
#       <td id="T_e8893_row0_col5" class="data row0 col5" >55.000000</td>
#       <td id="T_e8893_row0_col6" class="data row0 col6" >326</td>
#       <td id="T_e8893_row0_col7" class="data row0 col7" >3.950000</td>
#       <td id="T_e8893_row0_col8" class="data row0 col8" >3.980000</td>
#       <td id="T_e8893_row0_col9" class="data row0 col9" >2.430000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8893_row1_col0" class="data row1 col0" >0.210000</td>
#       <td id="T_e8893_row1_col1" class="data row1 col1" >Premium</td>
#       <td id="T_e8893_row1_col2" class="data row1 col2" >E</td>
#       <td id="T_e8893_row1_col3" class="data row1 col3" >SI1</td>
#       <td id="T_e8893_row1_col4" class="data row1 col4" >59.800000</td>
#       <td id="T_e8893_row1_col5" class="data row1 col5" >61.000000</td>
#       <td id="T_e8893_row1_col6" class="data row1 col6" >326</td>
#       <td id="T_e8893_row1_col7" class="data row1 col7" >3.890000</td>
#       <td id="T_e8893_row1_col8" class="data row1 col8" >3.840000</td>
#       <td id="T_e8893_row1_col9" class="data row1 col9" >2.310000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8893_row2_col0" class="data row2 col0" >0.230000</td>
#       <td id="T_e8893_row2_col1" class="data row2 col1" >Good</td>
#       <td id="T_e8893_row2_col2" class="data row2 col2" >E</td>
#       <td id="T_e8893_row2_col3" class="data row2 col3" >VS1</td>
#       <td id="T_e8893_row2_col4" class="data row2 col4" >56.900000</td>
#       <td id="T_e8893_row2_col5" class="data row2 col5" >65.000000</td>
#       <td id="T_e8893_row2_col6" class="data row2 col6" >327</td>
#       <td id="T_e8893_row2_col7" class="data row2 col7" >4.050000</td>
#       <td id="T_e8893_row2_col8" class="data row2 col8" >4.070000</td>
#       <td id="T_e8893_row2_col9" class="data row2 col9" >2.310000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8893_row3_col0" class="data row3 col0" >0.290000</td>
#       <td id="T_e8893_row3_col1" class="data row3 col1" >Premium</td>
#       <td id="T_e8893_row3_col2" class="data row3 col2" >I</td>
#       <td id="T_e8893_row3_col3" class="data row3 col3" >VS2</td>
#       <td id="T_e8893_row3_col4" class="data row3 col4" >62.400000</td>
#       <td id="T_e8893_row3_col5" class="data row3 col5" >58.000000</td>
#       <td id="T_e8893_row3_col6" class="data row3 col6" >334</td>
#       <td id="T_e8893_row3_col7" class="data row3 col7" >4.200000</td>
#       <td id="T_e8893_row3_col8" class="data row3 col8" >4.230000</td>
#       <td id="T_e8893_row3_col9" class="data row3 col9" >2.630000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8893_row4_col0" class="data row4 col0" >0.310000</td>
#       <td id="T_e8893_row4_col1" class="data row4 col1" >Good</td>
#       <td id="T_e8893_row4_col2" class="data row4 col2" >J</td>
#       <td id="T_e8893_row4_col3" class="data row4 col3" >SI2</td>
#       <td id="T_e8893_row4_col4" class="data row4 col4" >63.300000</td>
#       <td id="T_e8893_row4_col5" class="data row4 col5" >58.000000</td>
#       <td id="T_e8893_row4_col6" class="data row4 col6" >335</td>
#       <td id="T_e8893_row4_col7" class="data row4 col7" >4.340000</td>
#       <td id="T_e8893_row4_col8" class="data row4 col8" >4.350000</td>
#       <td id="T_e8893_row4_col9" class="data row4 col9" >2.750000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8893_row5_col0" class="data row5 col0" >0.240000</td>
#       <td id="T_e8893_row5_col1" class="data row5 col1" >Very Good</td>
#       <td id="T_e8893_row5_col2" class="data row5 col2" >J</td>
#       <td id="T_e8893_row5_col3" class="data row5 col3" >VVS2</td>
#       <td id="T_e8893_row5_col4" class="data row5 col4" >62.800000</td>
#       <td id="T_e8893_row5_col5" class="data row5 col5" >57.000000</td>
#       <td id="T_e8893_row5_col6" class="data row5 col6" >336</td>
#       <td id="T_e8893_row5_col7" class="data row5 col7" >3.940000</td>
#       <td id="T_e8893_row5_col8" class="data row5 col8" >3.960000</td>
#       <td id="T_e8893_row5_col9" class="data row5 col9" >2.480000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8893_row6_col0" class="data row6 col0" >0.240000</td>
#       <td id="T_e8893_row6_col1" class="data row6 col1" >Very Good</td>
#       <td id="T_e8893_row6_col2" class="data row6 col2" >I</td>
#       <td id="T_e8893_row6_col3" class="data row6 col3" >VVS1</td>
#       <td id="T_e8893_row6_col4" class="data row6 col4" >62.300000</td>
#       <td id="T_e8893_row6_col5" class="data row6 col5" >57.000000</td>
#       <td id="T_e8893_row6_col6" class="data row6 col6" >336</td>
#       <td id="T_e8893_row6_col7" class="data row6 col7" >3.950000</td>
#       <td id="T_e8893_row6_col8" class="data row6 col8" >3.980000</td>
#       <td id="T_e8893_row6_col9" class="data row6 col9" >2.470000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8893_row7_col0" class="data row7 col0" >0.260000</td>
#       <td id="T_e8893_row7_col1" class="data row7 col1" >Very Good</td>
#       <td id="T_e8893_row7_col2" class="data row7 col2" >H</td>
#       <td id="T_e8893_row7_col3" class="data row7 col3" >SI1</td>
#       <td id="T_e8893_row7_col4" class="data row7 col4" >61.900000</td>
#       <td id="T_e8893_row7_col5" class="data row7 col5" >55.000000</td>
#       <td id="T_e8893_row7_col6" class="data row7 col6" >337</td>
#       <td id="T_e8893_row7_col7" class="data row7 col7" >4.070000</td>
#       <td id="T_e8893_row7_col8" class="data row7 col8" >4.110000</td>
#       <td id="T_e8893_row7_col9" class="data row7 col9" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_e8893_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8893_row8_col0" class="data row8 col0" >0.220000</td>
#       <td id="T_e8893_row8_col1" class="data row8 col1" >Fair</td>
#       <td id="T_e8893_row8_col2" class="data row8 col2" >E</td>
#       <td id="T_e8893_row8_col3" class="data row8 col3" >VS2</td>
#       <td id="T_e8893_row8_col4" class="data row8 col4" >65.100000</td>
#       <td id="T_e8893_row8_col5" class="data row8 col5" >61.000000</td>
#       <td id="T_e8893_row8_col6" class="data row8 col6" >337</td>
#       <td id="T_e

# %%
highlight = lambda x: ['background: grey' if (x.Country == 'USA') or (x.Country == 'Canada') else 'background: green' for i in x]

hdf.style.apply(highlight,axis=1)
# Out:
# <style type="text/css">
# #T_abde5_row0_col0, #T_abde5_row0_col1, #T_abde5_row0_col2, #T_abde5_row1_col0, #T_abde5_row1_col1, #T_abde5_row1_col2, #T_abde5_row2_col0, #T_abde5_row2_col1, #T_abde5_row2_col2, #T_abde5_row3_col0, #T_abde5_row3_col1, #T_abde5_row3_col2, #T_abde5_row4_col0, #T_abde5_row4_col1, #T_abde5_row4_col2, #T_abde5_row9_col0, #T_abde5_row9_col1, #T_abde5_row9_col2, #T_abde5_row10_col0, #T_abde5_row10_col1, #T_abde5_row10_col2 {
#   background: grey;
# }
# #T_abde5_row5_col0, #T_abde5_row5_col1, #T_abde5_row5_col2, #T_abde5_row6_col0, #T_abde5_row6_col1, #T_abde5_row6_col2, #T_abde5_row7_col0, #T_abde5_row7_col1, #T_abde5_row7_col2, #T_abde5_row8_col0, #T_abde5_row8_col1, #T_abde5_row8_col2, #T_abde5_row11_col0, #T_abde5_row11_col1, #T_abde5_row11_col2 {
#   background: green;
# }
# </style>
# <table id="T_abde5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Product</th>
#       <th class="col_heading level0 col1" >Amount</th>
#       <th class="col_heading level0 col2" >Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abde5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abde5_row0_col0" class="data row0 col0" >Banana</td>
#       <td id="T_abde5_row0_col1" class="data row0 col1" >1000</td>
#       <td id="T_abde5_row0_col2" class="data row0 col2" >USA</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abde5_row1_col0" class="data row1 col0" >Carrots</td>
#       <td id="T_abde5_row1_col1" class="data row1 col1" >1500</td>
#       <td id="T_abde5_row1_col2" class="data row1 col2" >USA</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abde5_row2_col0" class="data row2 col0" >Beans</td>
#       <td id="T_abde5_row2_col1" class="data row2 col1" >1600</td>
#       <td id="T_abde5_row2_col2" class="data row2 col2" >USA</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abde5_row3_col0" class="data row3 col0" >Orange</td>
#       <td id="T_abde5_row3_col1" class="data row3 col1" >2000</td>
#       <td id="T_abde5_row3_col2" class="data row3 col2" >USA</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abde5_row4_col0" class="data row4 col0" >Orange</td>
#       <td id="T_abde5_row4_col1" class="data row4 col1" >2000</td>
#       <td id="T_abde5_row4_col2" class="data row4 col2" >USA</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_abde5_row5_col0" class="data row5 col0" >Banana</td>
#       <td id="T_abde5_row5_col1" class="data row5 col1" >400</td>
#       <td id="T_abde5_row5_col2" class="data row5 col2" >China</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_abde5_row6_col0" class="data row6 col0" >Carrots</td>
#       <td id="T_abde5_row6_col1" class="data row6 col1" >1200</td>
#       <td id="T_abde5_row6_col2" class="data row6 col2" >China</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_abde5_row7_col0" class="data row7 col0" >Beans</td>
#       <td id="T_abde5_row7_col1" class="data row7 col1" >1500</td>
#       <td id="T_abde5_row7_col2" class="data row7 col2" >China</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_abde5_row8_col0" class="data row8 col0" >Orange</td>
#       <td id="T_abde5_row8_col1" class="data row8 col1" >4000</td>
#       <td id="T_abde5_row8_col2" class="data row8 col2" >China</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_abde5_row9_col0" class="data row9 col0" >Banana</td>
#       <td id="T_abde5_row9_col1" class="data row9 col1" >2000</td>
#       <td id="T_abde5_row9_col2" class="data row9 col2" >Canada</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_abde5_row10_col0" class="data row10 col0" >Carrots</td>
#       <td id="T_abde5_row10_col1" class="data row10 col1" >2000</td>
#       <td id="T_abde5_row10_col2" class="data row10 col2" >Canada</td>
#     </tr>
#     <tr>
#       <th id="T_abde5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_abde5_row11_col0" class="data row11 col0" >Beans</td>
#       <td id="T_abde5_row11_col1" class="data row11 col1" >2000</td>
#       <td id="T_abde5_row11_col2" class="data row11 col2" >Mexico</td>
#     </tr>
#   </tbody>
# </table>
